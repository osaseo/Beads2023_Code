# %% [markdown]
# ### 2 Creating Spectral Profiles by Hand
#
# This notebook is for creating spectral profiles by hand using `CIAO SHERPA` and `XSPEC`
#
# 1. Set SDSS 1531 parameters
# 2.
# 3.

# %%
path_to_beads = '/Users/osaseomoruyi/Dropbox (Harvard University)/BeadsMultiwavelength/'

# %%
import os
import re
import glob
import shutil
import logging
from types import SimpleNamespace # cute trick to turn dictionaries into separate variables

import warnings
warnings.filterwarnings("ignore")

import json

import numpy as np
import numpy.polynomial.polynomial as poly

import scipy

from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from astropy.io import fits
from astropy.io import ascii
from astropy.table import QTable
from astropy import units as u
from astropy import constants as const
from astropy.cosmology import FlatLambdaCDM
import pyregion

# Run CIAO within Python! 
import ciao_contrib.runtool as ciao
from sherpa.astro import ui as sherpa
from sherpa.astro import xspec as xspec
import lightcurves as lc
from pycrates import read_file

import multiprocessing

import importlib

# %%
#import my own functions: you can see them in full in the utils folder
util_path = path_to_beads + 'Notebooks/Beads20/utils/'
sys.path.append(util_path)

import plotting_functions_ciao as pf
import chandra_functions as cf

# %%
#uncomment if need to reload module
importlib.reload(cf)
# Out:
# <module 'chandra_functions' from '/Users/osaseomoruyi/Dropbox (Harvard University)/BeadsMultiwavelength/Notebooks/Beads20/utils/chandra_functions.py'>

# %% [markdown]
# ## 1. Set SDSS-1531 Specific Parameters

# %%
obsids = ['17218', '18689']
nH = 1.79e20 
kT_guess = 4.0 # keV
abundance_guess = 0.3
z = 0.335
r500 = 840 # kpc

acis_pixel_scale = 0.4920 * u.arcsec

cosmo = FlatLambdaCDM(H0=70, Om0=0.3, Tcmb0=2.725)
angular_diameter_distance = cosmo.angular_diameter_distance(z=z) # in Mpc
kpc_per_arcsec = cosmo.kpc_proper_per_arcmin(z=z).to(u.kpc / u.arcsec)
print(f'At a redshift of {z}, the angular diameter distance is {np.round(angular_diameter_distance,4)}')
print(f'At a redshift of {z}, we have {np.round(kpc_per_arcsec,4)}')
# Out:
# At a redshift of 0.335, the angular diameter distance is 990.0203 Mpc
# At a redshift of 0.335, we have 4.7998 kpc / arcsec

# %% [markdown]
# ## 2. Define annulus region to use
#
# Define series of annuli in DS9. Below the annuli are defined in equal spacings from 1-60" to mimic the ClusterPyXT fitting region

# %%
annuli_to_use = ['annulus_60arcsec.reg', 'annulus_alexey.reg', 'background.reg']
annuli_labels = ['ClusterPyXT Annuli', 'Alexey Tprof Annuli', 'BG']

for idf, annuli_file in enumerate(annuli_to_use):
    # Also populate a list of individual annuli in this region stack
    with open(annuli_file) as f:
        list_of_annuli_strings = [ line.strip() for line in f ]

    fig, ax = cf.show_img('ff.img.07-2.fits', regions=annuli_file)
    ax.set_title(annuli_labels[idf])

# %% [markdown]
# ## 3. Create and Plot Surface Brightness Profile

# %% [markdown]
# Extract the surface brightness profile using `CIAO`.
# - need to create `background.reg` by drawing an annulust way outside the cluster that looks like background noise

# %%
annuli_id=1
for obsid in obsids: 
    print(f'Extracting radial profile for {obsid}')
    ciao.dmextract(f'{obsid}_reproj_evt.fits[energy=500:7000][bin sky=@{annuli_to_use[annuli_id]}]', 
                outfile=f'v{obsid}_flux_rprofile.fits', 
                bkg=f'{obsid}_reproj_evt.fits[energy=500:7000][bin sky=region(background.reg)]', 
                opt='generic',
                exp=f'{obsid}_broad_thresh.expmap',
                bkgexp=f'{obsid}_broad_thresh.expmap',
                clobber=True)
    print(f'Made v{obsid}_flux_rprofile.fits')
# Out:
# Extracting radial profile for 17218
# Made v17218_flux_rprofile.fits
# Extracting radial profile for 18689
# Made v18689_flux_rprofile.fits

# %% [markdown]
# Plot the surface brightness profile

# %%
fig, ax = plt.subplots(figsize=(10,10))

for obsid in obsids:
    surface_brightness_profile = read_file(f'{obsid}_flux_rprofile.fits')

    rmin_rmax_in_pixel_units = surface_brightness_profile.get_column("r").values # this will give you an array of radii
    rmid_in_pixel_units = surface_brightness_profile.get_column("rmid").values
    
    sur_bri = surface_brightness_profile.get_column("sur_bri").values
    sur_bri_err = surface_brightness_profile.get_column("sur_bri_err").values
    sur_flux = surface_brightness_profile.get_column("sur_flux").values
    sur_flux_err = surface_brightness_profile.get_column("sur_flux_err").values
    cel_flux = surface_brightness_profile.get_column("cel_flux").values # The CEL_FLUX and CEL_FLUX_ERR columns are also provided, with transforms applied to convert values in pixels to ones in arcsec (if the appropriate WCS information is provided in the input file).
    cel_flux_err = surface_brightness_profile.get_column("cel_flux_err").values


    radius_to_plot = rmid_in_pixel_units * acis_pixel_scale.value * kpc_per_arcsec.value  # convert to kpc but ditch astropy units
    radius_err_to_plot = ((rmin_rmax_in_pixel_units[:,1] - rmin_rmax_in_pixel_units[:,0])/2) * acis_pixel_scale.value * kpc_per_arcsec.value
    
    ax.errorbar(radius_to_plot, cel_flux,yerr=cel_flux_err, xerr=radius_err_to_plot, marker="o", ls='none') # ls=None doesn't work, stupidly

ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"Surface Brightness (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')
# Out:
# Text(0.5, 0, 'Radius (arcsec)')

# %% [markdown]
# ## 4. Extract and Fit the spectra from the defined annuli
#
# Below we extract the spectra in each annuli using `CIAO`.

# %%
really_run_this = False

if really_run_this is True:
    unique_run_name = 'avery'

    #open 60 arcsec annuli
    with open(annuli_to_use[0]) as f:
            list_of_annuli_strings = [ line.strip() for line in f ]

    # Clean up existing files that conflict with this run name
    existing_run_files = glob.glob(f'*{unique_run_name}*')
    for f in existing_run_files:
    os.remove(f)


    # First, extract the spectra. This'll take a while :( 
    for i, annulus_string in enumerate(tqdm(list_of_annuli_strings)):
        
        for obsid in obsids:

            print(f'Extracting spectra from region {i} for {obsid}...') 
            ciao.specextract.punlearn()

            ciao.specextract(infile=f'{obsid}_reproj_evt.fits[sky={annulus_string}]',
                            outroot=f'{unique_run_name}_{obsid}_{i}',
                            bkgfile=f'{obsid}_reproj_evt.fits[sky=region(background.reg)]',
                            clobber=True,
                            parallel=True,
                            verbose=5)

            print(f'Created spectra and respones files: {unique_run_name}_{obsid}_{i}.*\n')
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# Extracting spectra from region 0 for 17218...
# Created spectra and respones files: avery_17218_0.*
#
# Extracting spectra from region 0 for 18689...
# Created spectra and respones files: avery_18689_0.*
#
# Extracting spectra from region 1 for 17218...
# Created spectra and respones files: avery_17218_1.*
#
# Extracting spectra from region 1 for 18689...
# Created spectra and respones files: avery_18689_1.*
#
# Extracting spectra from region 2 for 17218...
# Created spectra and respones files: avery_17218_2.*
#
# Extracting spectra from region 2 for 18689...
# Created spectra and respones files: avery_18689_2.*
#
# Extracting spectra from region 3 for 17218...
# Created spectra and respones files: avery_17218_3.*
#
# Extracting spectra from region 3 for 18689...
# Created spectra and respones files: avery_18689_3.*
#
# Extracting spectra from region 4 for 17218...
# Created spectra and respones files: avery_17218_4.*
#
# Extracting spectra from region 4 for 18689...
# Created spectra and respones files: avery_18689_4.*
#
# Extracting spectra from region 5 for 17218...
# Created spectra and respones files: avery_17218_5.*
#
# Extracting spectra from region 5 for 18689...
# Created spectra and respones files: avery_18689_5.*
#
# Extracting spectra from region 6 for 17218...
# Created spectra and respones files: avery_17218_6.*
#
# Extracting spectra from region 6 for 18689...
# Created spectra and respones files: avery_18689_6.*
#
# Extracting spectra from region 7 for 17218...
# Created spectra and respones files: avery_17218_7.*
#
# Extracting spectra from region 7 for 18689...
# Created spectra and respones files: avery_18689_7.*
#
# Extracting spectra from region 8 for 17218...
# Created spectra and respones files: avery_17218_8.*
#
# Extracting spectra from region 8 for 18689...
# Created spectra and respones files: avery_18689_8.*
#
# Extracting spectra from region 9 for 17218...
# Created spectra and respones files: avery_17218_9.*
#
# Extracting spectra from region 9 for 18689...
# Created spectra and respones files: avery_18689_9.*
#
# Extracting spectra from region 10 for 17218...
# Created spectra and respones files: avery_17218_10.*
#
# Extracting spectra from region 10 for 18689...
# Created spectra and respones files: avery_18689_10.*
#
# Extracting spectra from region 11 for 17218...
# Created spectra and respones files: avery_17218_11.*
#
# Extracting spectra from region 11 for 18689...
# Created spectra and respones files: avery_18689_11.*
#
# Extracting spectra from region 12 for 17218...
# Created spectra and respones files: avery_17218_12.*
#
# Extracting spectra from region 12 for 18689...
# Created spectra and respones files: avery_18689_12.*
#
# Extracting spectra from region 13 for 17218...
# Created spectra and respones files: avery_17218_13.*
#
# Extracting spectra from region 13 for 18689...
# Created spectra and respones files: avery_18689_13.*
#
# Extracting spectra from region 14 for 17218...
# Created spectra and respones files: avery_17218_14.*
#
# Extracting spectra from region 14 for 18689...
# Created spectra and respones files: avery_18689_14.*
#
# Extracting spectra from region 15 for 17218...
# Created spectra and respones files: avery_17218_15.*
#
# Extracting spectra from region 15 for 18689...
# Created spectra and respones files: avery_18689_15.*
#
# Extracting spectra from region 16 for 17218...
# Created spectra and respones files: avery_17218_16.*
#
# Extracting spectra from region 16 for 18689...
# Created spectra and respones files: avery_18689_16.*
#
# Extracting spectra from region 17 for 17218...
# Created spectra and respones files: avery_17218_17.*
#
# Extracting spectra from region 17 for 18689...
# Created spectra and respones files: avery_18689_17.*
#
# Extracting spectra from region 18 for 17218...
# Created spectra and respones files: avery_17218_18.*
#
# Extracting spectra from region 18 for 18689...
# Created spectra and respones files: avery_18689_18.*
#
# Extracting spectra from region 19 for 17218...
# Created spectra and respones files: avery_17218_19.*
#
# Extracting spectra from region 19 for 18689...
# Created spectra and respones files: avery_18689_19.*
#
# Extracting spectra from region 20 for 17218...
# Created spectra and respones files: avery_17218_20.*
#
# Extracting spectra from region 20 for 18689...
# Created spectra and respones files: avery_18689_20.*

# %% [markdown]
# ### Fit the spectra with an APEC model in Sherpa

# %%
unique_run_name = 'avery'

kTs_list = []
kT_errs_list = []
norms_list = []
norm_errs_list = []

sherpa_log = logging.getLogger("Sherpa")
sherpa_log.setLevel(logging.ERROR)

#open 60 arcsec annuli
with open(annuli_to_use[0]) as f:
        list_of_annuli_strings = [ line.strip() for line in f ]
        
for region_number in tqdm(range(len(list_of_annuli_strings))): 

    # Load in the data and set the model for each
    print(f'Loading data and model for region {region_number}...')
    
    for i, obsid in enumerate(obsids):
        pi_file_name = f'{unique_run_name}_{obsid}_{region_number}_grp.pi'
        bkg_pi_file_name = f'{unique_run_name}_{obsid}_{region_number}_bkg.pi'
        sherpa.load_pha(i, pi_file_name)
        sherpa.load_bkg(i, bkg_pi_file_name) # 
        sherpa.subtract(i) # subtract the background
        sherpa.set_source(i, sherpa.xsphabs.phabs * sherpa.xsapec.apec)

    print(f'Fitting for region {region_number}...')

    # Set energy range to fit to
    sherpa.set_analysis('energy')
    low_energy_cutoff = 0.3  # [units: keV]
    high_energy_cutoff = 7.0  # [units: keV]
    sherpa.ignore(f":{low_energy_cutoff}, {high_energy_cutoff}:")

    # set model parameters
    phabs.nH = nH / 1e22
    apec.kT = kT_guess
    apec.Abundanc = abundance_guess
    apec.redshift = z
    apec.norm = 1.0

    # Freeze (don't fit) and thaw (fit) parameters 
    sherpa.freeze(phabs.nH, apec.redshift, apec.Abundanc)
    sherpa.thaw(apec.kT, apec.norm)
    
    # Fit the model to the data
    sherpa.fit(0,1)
    basic_fit_results = sherpa.get_fit_results()
    print(basic_fit_results)

    # Now determine confidence intervals
    sherpa.set_conf_opt('numcores', 1) # conf() multiprocessing is kinda broken, I think

    # grab the goodness-of-fit
    sherpa.calc_stat_info()
    rstat = sherpa.get_stat_info()[0].rstat

    # Warn the user if the fit is bad 
    if rstat > 3.0:
        print(f'WARNING: Goodness-of-fit for {region_number} is {rstat}, this is bad!')
    sherpa.conf()
    fit_results = sherpa.get_conf_results()

    kT = fit_results.parvals[0]
    kTs_list.append(kT) 

    kT_mean_error = (fit_results.parmins[0] + fit_results.parmaxes[0]) / 2
    kT_errs_list.append(kT_mean_error)

    norm_fit = fit_results.parvals[1]
    norms_list.append(norm_fit)
    
    norm_mean_error = (fit_results.parmins[1] + fit_results.parmaxes[1]) / 2
    norm_errs_list.append(norm_mean_error)

    kTs = np.array(kTs_list) * u.keV
    kT_errs = np.array(kT_errs_list) * u.keV
    norms = np.array(norms_list)
    norm_errs = np.array(norm_errs_list)    

    # make a plot for this fit :) 
    
    sherpa.get_data_plot_prefs()['ylog'] = True
    sherpa.get_data_plot_prefs()['xlog'] = True
    sherpa.plot_fit_delchi(0)
    sherpa.plot_fit_delchi(1, overplot=True)

    # hijack the plot axes to override title
    fig = plt.gcf()
    fig.set_size_inches(12, 8)
    axs = fig.get_axes()
    axs[0].set_title(f'{unique_run_name} region {region_number} ({np.round(radius_to_plot[1],0)} kpc) | kT = {np.round(kT,3)} ± {np.round(kT_mean_error,3)} keV | Stat = {np.round(rstat,3)}')
    plt.savefig(f'{unique_run_name}_{region_number}_fit.pdf', dpi=300)
    plt.close()
    sherpa.clean()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# Loading data and model for region 0...
# read ARF file avery_17218_0.arf
# read RMF file avery_17218_0.rmf
# read ARF (background) file avery_17218_0_bkg.arf
# read RMF (background) file avery_17218_0_bkg.rmf
# read background file avery_17218_0_bkg.pi
# read ARF (background) file avery_17218_0_bkg.arf
# read RMF (background) file avery_17218_0_bkg.rmf
# read ARF file avery_18689_0.arf
# read RMF file avery_18689_0.rmf
# read ARF (background) file avery_18689_0_bkg.arf
# read RMF (background) file avery_18689_0_bkg.rmf
# read background file avery_18689_0_bkg.pi
# read ARF (background) file avery_18689_0_bkg.arf
# read RMF (background) file avery_18689_0_bkg.rmf
# Fitting for region 0...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 3.77785e+10
# Final fit statistic   = 19.41 at function evaluation 18
# Data points           = 41
# Degrees of freedom    = 39
# Probability [Q-value] = 0.996337
# Reduced statistic     = 0.497691
# Change in statistic   = 3.77785e+10
#    apec.kT        2.40397      +/- 0.235814
#    apec.norm      0.000120584  +/- 7.23575e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (2.4039738300409548, 0.00012058385866016761)
# statval        = 19.409964686464733
# istatval       = 37778518776.599686
# dstatval       = 37778518757.18972
# numpoints      = 41
# dof            = 39
# qval           = 0.9963370892062211
# rstat          = 0.49769140221704444
# message        = successful termination
# nfev           = 18
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 10.2019
# Data points           = 26
# Degrees of freedom    = 24
# Probability [Q-value] = 0.993663
# Reduced statistic     = 0.425079
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 9.20806
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.757054
# Reduced statistic     = 0.708313
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 19.41
# Data points           = 41
# Degrees of freedom    = 39
# Probability [Q-value] = 0.996337
# Reduced statistic     = 0.497691
# apec.kT lower bound:	-0.22906
# apec.kT upper bound:	0.288478
# apec.norm lower bound:	-7.4782e-06
# apec.norm upper bound:	7.25176e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           2.40397     -0.22906     0.288478
#    apec.norm     0.000120584  -7.4782e-06  7.25176e-06
# Loading data and model for region 1...
# read ARF file avery_17218_1.arf
# read RMF file avery_17218_1.rmf
# read ARF (background) file avery_17218_1_bkg.arf
# read RMF (background) file avery_17218_1_bkg.rmf
# read background file avery_17218_1_bkg.pi
# read ARF (background) file avery_17218_1_bkg.arf
# read RMF (background) file avery_17218_1_bkg.rmf
# read ARF file avery_18689_1.arf
# read RMF file avery_18689_1.rmf
# read ARF (background) file avery_18689_1_bkg.arf
# read RMF (background) file avery_18689_1_bkg.rmf
# read background file avery_18689_1_bkg.pi
# read ARF (background) file avery_18689_1_bkg.arf
# read RMF (background) file avery_18689_1_bkg.rmf
# Fitting for region 1...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 4.22652e+10
# Final fit statistic   = 23.6897 at function evaluation 16
# Data points           = 38
# Degrees of freedom    = 36
# Probability [Q-value] = 0.94279
# Reduced statistic     = 0.658046
# Change in statistic   = 4.22652e+10
#    apec.kT        2.51145      +/- 0.284757
#    apec.norm      0.000104144  +/- 6.74639e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (2.5114492398088832, 0.00010414430431465484)
# statval        = 23.689668730604748
# istatval       = 42265238211.64294
# dstatval       = 42265238187.95327
# numpoints      = 38
# dof            = 36
# qval           = 0.9427895243697489
# rstat          = 0.6580463536279096
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 13.6197
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.914426
# Reduced statistic     = 0.619076
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 10.07
# Data points           = 14
# Degrees of freedom    = 12
# Probability [Q-value] = 0.60982
# Reduced statistic     = 0.839166
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 23.6897
# Data points           = 38
# Degrees of freedom    = 36
# Probability [Q-value] = 0.94279
# Reduced statistic     = 0.658046
# apec.kT lower bound:	-0.275214
# apec.kT upper bound:	0.328712
# apec.norm lower bound:	-6.84656e-06
# apec.norm upper bound:	6.84838e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           2.51145    -0.275214     0.328712
#    apec.norm     0.000104144 -6.84656e-06  6.84838e-06
# Loading data and model for region 2...
# read ARF file avery_17218_2.arf
# read RMF file avery_17218_2.rmf
# read ARF (background) file avery_17218_2_bkg.arf
# read RMF (background) file avery_17218_2_bkg.rmf
# read background file avery_17218_2_bkg.pi
# read ARF (background) file avery_17218_2_bkg.arf
# read RMF (background) file avery_17218_2_bkg.rmf
# read ARF file avery_18689_2.arf
# read RMF file avery_18689_2.rmf
# read ARF (background) file avery_18689_2_bkg.arf
# read RMF (background) file avery_18689_2_bkg.rmf
# read background file avery_18689_2_bkg.pi
# read ARF (background) file avery_18689_2_bkg.arf
# read RMF (background) file avery_18689_2_bkg.rmf
# Fitting for region 2...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 3.42134e+10
# Final fit statistic   = 31.9716 at function evaluation 13
# Data points           = 49
# Degrees of freedom    = 47
# Probability [Q-value] = 0.953941
# Reduced statistic     = 0.680246
# Change in statistic   = 3.42134e+10
#    apec.kT        3.39325      +/- 0.427105
#    apec.norm      0.000121002  +/- 7.07343e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (3.3932523554721015, 0.00012100170706789252)
# statval        = 31.971567025249843
# istatval       = 34213370751.87305
# dstatval       = 34213370719.901485
# numpoints      = 49
# dof            = 47
# qval           = 0.953940673112445
# rstat          = 0.6802461069202095
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 22.5647
# Data points           = 31
# Degrees of freedom    = 29
# Probability [Q-value] = 0.796077
# Reduced statistic     = 0.778093
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 9.40687
# Data points           = 18
# Degrees of freedom    = 16
# Probability [Q-value] = 0.895717
# Reduced statistic     = 0.587929
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 31.9716
# Data points           = 49
# Degrees of freedom    = 47
# Probability [Q-value] = 0.953941
# Reduced statistic     = 0.680246
# apec.kT lower bound:	-0.418446
# apec.kT upper bound:	0.516031
# apec.norm lower bound:	-7.15512e-06
# apec.norm upper bound:	7.2318e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           3.39325    -0.418446     0.516031
#    apec.norm     0.000121002 -7.15512e-06   7.2318e-06
# Loading data and model for region 3...
# read ARF file avery_17218_3.arf
# read RMF file avery_17218_3.rmf
# read ARF (background) file avery_17218_3_bkg.arf
# read RMF (background) file avery_17218_3_bkg.rmf
# read background file avery_17218_3_bkg.pi
# read ARF (background) file avery_17218_3_bkg.arf
# read RMF (background) file avery_17218_3_bkg.rmf
# read ARF file avery_18689_3.arf
# read RMF file avery_18689_3.rmf
# read ARF (background) file avery_18689_3_bkg.arf
# read RMF (background) file avery_18689_3_bkg.rmf
# read background file avery_18689_3_bkg.pi
# read ARF (background) file avery_18689_3_bkg.arf
# read RMF (background) file avery_18689_3_bkg.rmf
# Fitting for region 3...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 4.44017e+10
# Final fit statistic   = 30.3936 at function evaluation 9
# Data points           = 41
# Degrees of freedom    = 39
# Probability [Q-value] = 0.836466
# Reduced statistic     = 0.779323
# Change in statistic   = 4.44017e+10
#    apec.kT        3.96002      +/- 0.618271
#    apec.norm      8.85476e-05  +/- 5.84443e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (3.9600190780634046, 8.854756335861633e-05)
# statval        = 30.393606307156045
# istatval       = 44401745280.34517
# dstatval       = 44401745249.95156
# numpoints      = 41
# dof            = 39
# qval           = 0.8364657013776757
# rstat          = 0.7793232386450268
# message        = successful termination
# nfev           = 9
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 25.3383
# Data points           = 27
# Degrees of freedom    = 25
# Probability [Q-value] = 0.443546
# Reduced statistic     = 1.01353
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 5.05526
# Data points           = 14
# Degrees of freedom    = 12
# Probability [Q-value] = 0.956108
# Reduced statistic     = 0.421272
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 30.3936
# Data points           = 41
# Degrees of freedom    = 39
# Probability [Q-value] = 0.836466
# Reduced statistic     = 0.779323
# apec.kT lower bound:	-0.556793
# apec.kT upper bound:	0.720748
# apec.norm lower bound:	-5.77027e-06
# apec.norm upper bound:	5.92767e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           3.96002    -0.556793     0.720748
#    apec.norm     8.85476e-05 -5.77027e-06  5.92767e-06
# Loading data and model for region 4...
# read ARF file avery_17218_4.arf
# read RMF file avery_17218_4.rmf
# read ARF (background) file avery_17218_4_bkg.arf
# read RMF (background) file avery_17218_4_bkg.rmf
# read background file avery_17218_4_bkg.pi
# read ARF (background) file avery_17218_4_bkg.arf
# read RMF (background) file avery_17218_4_bkg.rmf
# read ARF file avery_18689_4.arf
# read RMF file avery_18689_4.rmf
# read ARF (background) file avery_18689_4_bkg.arf
# read RMF (background) file avery_18689_4_bkg.rmf
# read background file avery_18689_4_bkg.pi
# read ARF (background) file avery_18689_4_bkg.arf
# read RMF (background) file avery_18689_4_bkg.rmf
# Fitting for region 4...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 5.56635e+10
# Final fit statistic   = 20.3623 at function evaluation 25
# Data points           = 35
# Degrees of freedom    = 33
# Probability [Q-value] = 0.958202
# Reduced statistic     = 0.617038
# Change in statistic   = 5.56635e+10
#    apec.kT        4.31863      +/- 0.773999
#    apec.norm      7.07453e-05  +/- 4.94886e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.318627356515936, 7.074529647946283e-05)
# statval        = 20.36226423074172
# istatval       = 55663481859.86244
# dstatval       = 55663481839.500175
# numpoints      = 35
# dof            = 33
# qval           = 0.9582018251632034
# rstat          = 0.6170383100224763
# message        = successful termination
# nfev           = 25
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 12.73
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.917785
# Reduced statistic     = 0.606192
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 7.63222
# Data points           = 12
# Degrees of freedom    = 10
# Probability [Q-value] = 0.664711
# Reduced statistic     = 0.763222
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 20.3623
# Data points           = 35
# Degrees of freedom    = 33
# Probability [Q-value] = 0.958202
# Reduced statistic     = 0.617038
# apec.kT lower bound:	-0.642659
# apec.kT upper bound:	0.859148
# apec.norm lower bound:	-4.84867e-06
# apec.norm upper bound:	4.98261e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.31863    -0.642659     0.859148
#    apec.norm     7.07453e-05 -4.84867e-06  4.98261e-06
# Loading data and model for region 5...
# read ARF file avery_17218_5.arf
# read RMF file avery_17218_5.rmf
# read ARF (background) file avery_17218_5_bkg.arf
# read RMF (background) file avery_17218_5_bkg.rmf
# read background file avery_17218_5_bkg.pi
# read ARF (background) file avery_17218_5_bkg.arf
# read RMF (background) file avery_17218_5_bkg.rmf
# read ARF file avery_18689_5.arf
# read RMF file avery_18689_5.rmf
# read ARF (background) file avery_18689_5_bkg.arf
# read RMF (background) file avery_18689_5_bkg.rmf
# read background file avery_18689_5_bkg.pi
# read ARF (background) file avery_18689_5_bkg.arf
# read RMF (background) file avery_18689_5_bkg.rmf
# Fitting for region 5...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 6.18012e+10
# Final fit statistic   = 14.6191 at function evaluation 16
# Data points           = 32
# Degrees of freedom    = 30
# Probability [Q-value] = 0.991721
# Reduced statistic     = 0.487304
# Change in statistic   = 6.18012e+10
#    apec.kT        5.35856      +/- 1.19977
#    apec.norm      6.06205e-05  +/- 4.39605e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (5.358562825315627, 6.062051564402203e-05)
# statval        = 14.619129510473343
# istatval       = 61801166479.840935
# dstatval       = 61801166465.2218
# numpoints      = 32
# dof            = 30
# qval           = 0.9917211350808609
# rstat          = 0.4873043170157781
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 11.2589
# Data points           = 22
# Degrees of freedom    = 20
# Probability [Q-value] = 0.939231
# Reduced statistic     = 0.562943
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.36027
# Data points           = 10
# Degrees of freedom    = 8
# Probability [Q-value] = 0.90976
# Reduced statistic     = 0.420033
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 14.6191
# Data points           = 32
# Degrees of freedom    = 30
# Probability [Q-value] = 0.991721
# Reduced statistic     = 0.487304
# apec.kT lower bound:	-1.03682
# apec.kT upper bound:	1.51098
# apec.norm lower bound:	-4.26353e-06
# apec.norm upper bound:	4.45635e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           5.35856     -1.03682      1.51098
#    apec.norm     6.06205e-05 -4.26353e-06  4.45635e-06
# Loading data and model for region 6...
# read ARF file avery_17218_6.arf
# read RMF file avery_17218_6.rmf
# read ARF (background) file avery_17218_6_bkg.arf
# read RMF (background) file avery_17218_6_bkg.rmf
# read background file avery_17218_6_bkg.pi
# read ARF (background) file avery_17218_6_bkg.arf
# read RMF (background) file avery_17218_6_bkg.rmf
# read ARF file avery_18689_6.arf
# read RMF file avery_18689_6.rmf
# read ARF (background) file avery_18689_6_bkg.arf
# read RMF (background) file avery_18689_6_bkg.rmf
# read background file avery_18689_6_bkg.pi
# read ARF (background) file avery_18689_6_bkg.arf
# read RMF (background) file avery_18689_6_bkg.rmf
# Fitting for region 6...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 6.28657e+10
# Final fit statistic   = 11.471 at function evaluation 12
# Data points           = 31
# Degrees of freedom    = 29
# Probability [Q-value] = 0.998499
# Reduced statistic     = 0.395553
# Change in statistic   = 6.28657e+10
#    apec.kT        4.09207      +/- 0.81752
#    apec.norm      6.31753e-05  +/- 4.73347e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.09207009769864, 6.317529552431989e-05)
# statval        = 11.471037240611896
# istatval       = 62865723801.05108
# dstatval       = 62865723789.58004
# numpoints      = 31
# dof            = 29
# qval           = 0.9984987148656225
# rstat          = 0.39555300829696194
# message        = successful termination
# nfev           = 12
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 5.89521
# Data points           = 19
# Degrees of freedom    = 17
# Probability [Q-value] = 0.993863
# Reduced statistic     = 0.346777
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 5.57583
# Data points           = 12
# Degrees of freedom    = 10
# Probability [Q-value] = 0.849553
# Reduced statistic     = 0.557583
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 11.471
# Data points           = 31
# Degrees of freedom    = 29
# Probability [Q-value] = 0.998499
# Reduced statistic     = 0.395553
# apec.kT lower bound:	-0.677217
# apec.kT upper bound:	0.944661
# apec.norm lower bound:	-4.70642e-06
# apec.norm upper bound:	4.78113e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.09207    -0.677217     0.944661
#    apec.norm     6.31753e-05 -4.70642e-06  4.78113e-06
# Loading data and model for region 7...
# read ARF file avery_17218_7.arf
# read RMF file avery_17218_7.rmf
# read ARF (background) file avery_17218_7_bkg.arf
# read RMF (background) file avery_17218_7_bkg.rmf
# read background file avery_17218_7_bkg.pi
# read ARF (background) file avery_17218_7_bkg.arf
# read RMF (background) file avery_17218_7_bkg.rmf
# read ARF file avery_18689_7.arf
# read RMF file avery_18689_7.rmf
# read ARF (background) file avery_18689_7_bkg.arf
# read RMF (background) file avery_18689_7_bkg.rmf
# read background file avery_18689_7_bkg.pi
# read ARF (background) file avery_18689_7_bkg.arf
# read RMF (background) file avery_18689_7_bkg.rmf
# Fitting for region 7...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 6.90063e+10
# Final fit statistic   = 14.4733 at function evaluation 13
# Data points           = 31
# Degrees of freedom    = 29
# Probability [Q-value] = 0.988705
# Reduced statistic     = 0.49908
# Change in statistic   = 6.90063e+10
#    apec.kT        3.36968      +/- 0.565461
#    apec.norm      6.06722e-05  +/- 4.79703e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (3.369682124164269, 6.067224408861741e-05)
# statval        = 14.473310561962734
# istatval       = 69006327618.66315
# dstatval       = 69006327604.18983
# numpoints      = 31
# dof            = 29
# qval           = 0.9887053233565946
# rstat          = 0.4990796745504391
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 9.82021
# Data points           = 20
# Degrees of freedom    = 18
# Probability [Q-value] = 0.937617
# Reduced statistic     = 0.545567
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 4.6531
# Data points           = 11
# Degrees of freedom    = 9
# Probability [Q-value] = 0.86344
# Reduced statistic     = 0.517011
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 14.4733
# Data points           = 31
# Degrees of freedom    = 29
# Probability [Q-value] = 0.988705
# Reduced statistic     = 0.49908
# apec.kT lower bound:	-0.503289
# apec.kT upper bound:	0.652368
# apec.norm lower bound:	-4.75217e-06
# apec.norm upper bound:	4.81935e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           3.36968    -0.503289     0.652368
#    apec.norm     6.06722e-05 -4.75217e-06  4.81935e-06
# Loading data and model for region 8...
# read ARF file avery_17218_8.arf
# read RMF file avery_17218_8.rmf
# read ARF (background) file avery_17218_8_bkg.arf
# read RMF (background) file avery_17218_8_bkg.rmf
# read background file avery_17218_8_bkg.pi
# read ARF (background) file avery_17218_8_bkg.arf
# read RMF (background) file avery_17218_8_bkg.rmf
# read ARF file avery_18689_8.arf
# read RMF file avery_18689_8.rmf
# read ARF (background) file avery_18689_8_bkg.arf
# read RMF (background) file avery_18689_8_bkg.rmf
# read background file avery_18689_8_bkg.pi
# read ARF (background) file avery_18689_8_bkg.arf
# read RMF (background) file avery_18689_8_bkg.rmf
# Fitting for region 8...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 7.53739e+10
# Final fit statistic   = 20.2954 at function evaluation 16
# Data points           = 29
# Degrees of freedom    = 27
# Probability [Q-value] = 0.818134
# Reduced statistic     = 0.751681
# Change in statistic   = 7.53739e+10
#    apec.kT        4.61713      +/- 1.16389
#    apec.norm      5.00361e-05  +/- 4.18245e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.617126048325499, 5.003605000087344e-05)
# statval        = 20.295388670121284
# istatval       = 75373905088.00424
# dstatval       = 75373905067.70885
# numpoints      = 29
# dof            = 27
# qval           = 0.8181340617208862
# rstat          = 0.7516810618563439
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 15.8778
# Data points           = 20
# Degrees of freedom    = 18
# Probability [Q-value] = 0.601078
# Reduced statistic     = 0.882098
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 4.41762
# Data points           = 9
# Degrees of freedom    = 7
# Probability [Q-value] = 0.730613
# Reduced statistic     = 0.631089
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 20.2954
# Data points           = 29
# Degrees of freedom    = 27
# Probability [Q-value] = 0.818134
# Reduced statistic     = 0.751681
# apec.kT lower bound:	-0.939982
# apec.kT upper bound:	1.37304
# apec.norm lower bound:	-4.09254e-06
# apec.norm upper bound:	4.27719e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.61713    -0.939982      1.37304
#    apec.norm     5.00361e-05 -4.09254e-06  4.27719e-06
# Loading data and model for region 9...
# read ARF file avery_17218_9.arf
# read RMF file avery_17218_9.rmf
# read ARF (background) file avery_17218_9_bkg.arf
# read RMF (background) file avery_17218_9_bkg.rmf
# read background file avery_17218_9_bkg.pi
# read ARF (background) file avery_17218_9_bkg.arf
# read RMF (background) file avery_17218_9_bkg.rmf
# read ARF file avery_18689_9.arf
# read RMF file avery_18689_9.rmf
# read ARF (background) file avery_18689_9_bkg.arf
# read RMF (background) file avery_18689_9_bkg.rmf
# read background file avery_18689_9_bkg.pi
# read ARF (background) file avery_18689_9_bkg.arf
# read RMF (background) file avery_18689_9_bkg.rmf
# Fitting for region 9...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 8.56761e+10
# Final fit statistic   = 9.27953 at function evaluation 9
# Data points           = 26
# Degrees of freedom    = 24
# Probability [Q-value] = 0.996936
# Reduced statistic     = 0.386647
# Change in statistic   = 8.56761e+10
#    apec.kT        4.03239      +/- 0.911621
#    apec.norm      4.56049e-05  +/- 4.08753e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.032393612321507, 4.560490068160208e-05)
# statval        = 9.279532247200947
# istatval       = 85676095090.49947
# dstatval       = 85676095081.21994
# numpoints      = 26
# dof            = 24
# qval           = 0.9969364810773663
# rstat          = 0.38664717696670614
# message        = successful termination
# nfev           = 9
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 7.16337
# Data points           = 17
# Degrees of freedom    = 15
# Probability [Q-value] = 0.952957
# Reduced statistic     = 0.477558
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 2.11616
# Data points           = 9
# Degrees of freedom    = 7
# Probability [Q-value] = 0.953132
# Reduced statistic     = 0.302309
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 9.27953
# Data points           = 26
# Degrees of freedom    = 24
# Probability [Q-value] = 0.996936
# Reduced statistic     = 0.386647
# apec.kT lower bound:	-0.767919
# apec.kT upper bound:	1.09695
# apec.norm lower bound:	-3.96051e-06
# apec.norm upper bound:	4.0976e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.03239    -0.767919      1.09695
#    apec.norm     4.56049e-05 -3.96051e-06   4.0976e-06
# Loading data and model for region 10...
# read ARF file avery_17218_10.arf
# read RMF file avery_17218_10.rmf
# read ARF (background) file avery_17218_10_bkg.arf
# read RMF (background) file avery_17218_10_bkg.rmf
# read background file avery_17218_10_bkg.pi
# read ARF (background) file avery_17218_10_bkg.arf
# read RMF (background) file avery_17218_10_bkg.rmf
# read ARF file avery_18689_10.arf
# read RMF file avery_18689_10.rmf
# read ARF (background) file avery_18689_10_bkg.arf
# read RMF (background) file avery_18689_10_bkg.rmf
# read background file avery_18689_10_bkg.pi
# read ARF (background) file avery_18689_10_bkg.arf
# read RMF (background) file avery_18689_10_bkg.rmf
# Fitting for region 10...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 8.1967e+10
# Final fit statistic   = 12.6082 at function evaluation 13
# Data points           = 27
# Degrees of freedom    = 25
# Probability [Q-value] = 0.980951
# Reduced statistic     = 0.50433
# Change in statistic   = 8.1967e+10
#    apec.kT        4.26985      +/- 1.03666
#    apec.norm      4.6442e-05   +/- 4.131e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.269852685425707, 4.644199726034041e-05)
# statval        = 12.608242550632912
# istatval       = 81967030830.36125
# dstatval       = 81967030817.753
# numpoints      = 27
# dof            = 25
# qval           = 0.9809507579750015
# rstat          = 0.5043297020253165
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 8.19289
# Data points           = 17
# Degrees of freedom    = 15
# Probability [Q-value] = 0.915817
# Reduced statistic     = 0.546192
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 4.41536
# Data points           = 10
# Degrees of freedom    = 8
# Probability [Q-value] = 0.81784
# Reduced statistic     = 0.55192
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 12.6082
# Data points           = 27
# Degrees of freedom    = 25
# Probability [Q-value] = 0.980951
# Reduced statistic     = 0.50433
# apec.kT lower bound:	-0.871843
# apec.kT upper bound:	1.34491
# apec.norm lower bound:	-4.00947e-06
# apec.norm upper bound:	4.15794e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.26985    -0.871843      1.34491
#    apec.norm      4.6442e-05 -4.00947e-06  4.15794e-06
# Loading data and model for region 11...
# read ARF file avery_17218_11.arf
# read RMF file avery_17218_11.rmf
# read ARF (background) file avery_17218_11_bkg.arf
# read RMF (background) file avery_17218_11_bkg.rmf
# read background file avery_17218_11_bkg.pi
# read ARF (background) file avery_17218_11_bkg.arf
# read RMF (background) file avery_17218_11_bkg.rmf
# read ARF file avery_18689_11.arf
# read RMF file avery_18689_11.rmf
# read ARF (background) file avery_18689_11_bkg.arf
# read RMF (background) file avery_18689_11_bkg.rmf
# read background file avery_18689_11_bkg.pi
# read ARF (background) file avery_18689_11_bkg.arf
# read RMF (background) file avery_18689_11_bkg.rmf
# Fitting for region 11...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 8.62288e+10
# Final fit statistic   = 9.31878 at function evaluation 16
# Data points           = 25
# Degrees of freedom    = 23
# Probability [Q-value] = 0.994763
# Reduced statistic     = 0.405164
# Change in statistic   = 8.62288e+10
#    apec.kT        5.35591      +/- 1.65847
#    apec.norm      4.17558e-05  +/- 3.73533e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (5.35591068776667, 4.175576633744479e-05)
# statval        = 9.31877888454985
# istatval       = 86228768981.77399
# dstatval       = 86228768972.45522
# numpoints      = 25
# dof            = 23
# qval           = 0.9947626027379052
# rstat          = 0.4051642993282544
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 5.89834
# Data points           = 16
# Degrees of freedom    = 14
# Probability [Q-value] = 0.968989
# Reduced statistic     = 0.42131
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.42043
# Data points           = 9
# Degrees of freedom    = 7
# Probability [Q-value] = 0.84358
# Reduced statistic     = 0.488634
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 9.31878
# Data points           = 25
# Degrees of freedom    = 23
# Probability [Q-value] = 0.994763
# Reduced statistic     = 0.405164
# apec.kT lower bound:	-1.36092
# apec.kT upper bound:	2.44423
# apec.norm lower bound:	-3.63574e-06
# apec.norm upper bound:	3.84434e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           5.35591     -1.36092      2.44423
#    apec.norm     4.17558e-05 -3.63574e-06  3.84434e-06
# Loading data and model for region 12...
# read ARF file avery_17218_12.arf
# read RMF file avery_17218_12.rmf
# read ARF (background) file avery_17218_12_bkg.arf
# read RMF (background) file avery_17218_12_bkg.rmf
# read background file avery_17218_12_bkg.pi
# read ARF (background) file avery_17218_12_bkg.arf
# read RMF (background) file avery_17218_12_bkg.rmf
# read ARF file avery_18689_12.arf
# read RMF file avery_18689_12.rmf
# read ARF (background) file avery_18689_12_bkg.arf
# read RMF (background) file avery_18689_12_bkg.rmf
# read background file avery_18689_12_bkg.pi
# read ARF (background) file avery_18689_12_bkg.arf
# read RMF (background) file avery_18689_12_bkg.rmf
# Fitting for region 12...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 9.62015e+10
# Final fit statistic   = 12.3791 at function evaluation 13
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.949047
# Reduced statistic     = 0.562688
# Change in statistic   = 9.62015e+10
#    apec.kT        4.8016       +/- 1.56116
#    apec.norm      3.65834e-05  +/- 3.69518e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.801596672625021, 3.658341889409601e-05)
# statval        = 12.37912660562142
# istatval       = 96201515657.77327
# dstatval       = 96201515645.39415
# numpoints      = 24
# dof            = 22
# qval           = 0.9490473579586881
# rstat          = 0.5626875729827918
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 8.71805
# Data points           = 17
# Degrees of freedom    = 15
# Probability [Q-value] = 0.891792
# Reduced statistic     = 0.581203
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.66108
# Data points           = 7
# Degrees of freedom    = 5
# Probability [Q-value] = 0.599167
# Reduced statistic     = 0.732216
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 12.3791
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.949047
# Reduced statistic     = 0.562688
# apec.kT lower bound:	-1.27067
# apec.kT upper bound:	2.36755
# apec.norm lower bound:	-3.57227e-06
# apec.norm upper bound:	3.80631e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT            4.8016     -1.27067      2.36755
#    apec.norm     3.65834e-05 -3.57227e-06  3.80631e-06
# Loading data and model for region 13...
# read ARF file avery_17218_13.arf
# read RMF file avery_17218_13.rmf
# read ARF (background) file avery_17218_13_bkg.arf
# read RMF (background) file avery_17218_13_bkg.rmf
# read background file avery_17218_13_bkg.pi
# read ARF (background) file avery_17218_13_bkg.arf
# read RMF (background) file avery_17218_13_bkg.rmf
# read ARF file avery_18689_13.arf
# read RMF file avery_18689_13.rmf
# read ARF (background) file avery_18689_13_bkg.arf
# read RMF (background) file avery_18689_13_bkg.rmf
# read background file avery_18689_13_bkg.pi
# read ARF (background) file avery_18689_13_bkg.arf
# read RMF (background) file avery_18689_13_bkg.rmf
# Fitting for region 13...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 9.72018e+10
# Final fit statistic   = 9.98594 at function evaluation 13
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.979094
# Reduced statistic     = 0.475521
# Change in statistic   = 9.72018e+10
#    apec.kT        3.54498      +/- 0.87951
#    apec.norm      3.73083e-05  +/- 3.9129e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (3.544977500655479, 3.730826463149322e-05)
# statval        = 9.985936379751061
# istatval       = 97201832657.2167
# dstatval       = 97201832647.23077
# numpoints      = 23
# dof            = 21
# qval           = 0.9790938669630667
# rstat          = 0.4755207799881458
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 4.63115
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.982441
# Reduced statistic     = 0.356243
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 5.35478
# Data points           = 8
# Degrees of freedom    = 6
# Probability [Q-value] = 0.499179
# Reduced statistic     = 0.892464
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 9.98594
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.979094
# Reduced statistic     = 0.475521
# apec.kT lower bound:	-0.709652
# apec.kT upper bound:	1.03192
# apec.norm lower bound:	-3.80438e-06
# apec.norm upper bound:	3.89424e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           3.54498    -0.709652      1.03192
#    apec.norm     3.73083e-05 -3.80438e-06  3.89424e-06
# Loading data and model for region 14...
# read ARF file avery_17218_14.arf
# read RMF file avery_17218_14.rmf
# read ARF (background) file avery_17218_14_bkg.arf
# read RMF (background) file avery_17218_14_bkg.rmf
# read background file avery_17218_14_bkg.pi
# read ARF (background) file avery_17218_14_bkg.arf
# read RMF (background) file avery_17218_14_bkg.rmf
# read ARF file avery_18689_14.arf
# read RMF file avery_18689_14.rmf
# read ARF (background) file avery_18689_14_bkg.arf
# read RMF (background) file avery_18689_14_bkg.rmf
# read background file avery_18689_14_bkg.pi
# read ARF (background) file avery_18689_14_bkg.arf
# read RMF (background) file avery_18689_14_bkg.rmf
# Fitting for region 14...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 9.63173e+10
# Final fit statistic   = 9.78389 at function evaluation 16
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.98816
# Reduced statistic     = 0.444722
# Change in statistic   = 9.63173e+10
#    apec.kT        5.29083      +/- 2.02416
#    apec.norm      3.43524e-05  +/- 3.52589e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (5.290825334772674, 3.435237429453333e-05)
# statval        = 9.783890481074902
# istatval       = 96317287528.50446
# dstatval       = 96317287518.72057
# numpoints      = 24
# dof            = 22
# qval           = 0.9881604988055548
# rstat          = 0.4447222945943137
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 5.30293
# Data points           = 16
# Degrees of freedom    = 14
# Probability [Q-value] = 0.981134
# Reduced statistic     = 0.378781
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 4.48096
# Data points           = 8
# Degrees of freedom    = 6
# Probability [Q-value] = 0.611881
# Reduced statistic     = 0.746826
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 9.78389
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.98816
# Reduced statistic     = 0.444722
# apec.kT lower bound:	-1.51607
# apec.kT upper bound:	3.23532
# apec.norm lower bound:	-3.41212e-06
# apec.norm upper bound:	3.62538e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           5.29083     -1.51607      3.23532
#    apec.norm     3.43524e-05 -3.41212e-06  3.62538e-06
# Loading data and model for region 15...
# read ARF file avery_17218_15.arf
# read RMF file avery_17218_15.rmf
# read ARF (background) file avery_17218_15_bkg.arf
# read RMF (background) file avery_17218_15_bkg.rmf
# read background file avery_17218_15_bkg.pi
# read ARF (background) file avery_17218_15_bkg.arf
# read RMF (background) file avery_17218_15_bkg.rmf
# read ARF file avery_18689_15.arf
# read RMF file avery_18689_15.rmf
# read ARF (background) file avery_18689_15_bkg.arf
# read RMF (background) file avery_18689_15_bkg.rmf
# read background file avery_18689_15_bkg.pi
# read ARF (background) file avery_18689_15_bkg.arf
# read RMF (background) file avery_18689_15_bkg.rmf
# Fitting for region 15...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.06495e+11
# Final fit statistic   = 31.6412 at function evaluation 16
# Data points           = 25
# Degrees of freedom    = 23
# Probability [Q-value] = 0.107839
# Reduced statistic     = 1.3757
# Change in statistic   = 1.06495e+11
#    apec.kT        3.16592      +/- 0.887044
#    apec.norm      3.27461e-05  +/- 3.90223e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (3.1659220172590308, 3.274606198025587e-05)
# statval        = 31.64118132364251
# istatval       = 106495125368.2003
# dstatval       = 106495125336.55913
# numpoints      = 25
# dof            = 23
# qval           = 0.10783879045265926
# rstat          = 1.3757035358105438
# message        = successful termination
# nfev           = 16
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 23.5342
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.0356952
# Reduced statistic     = 1.81032
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 8.107
# Data points           = 10
# Degrees of freedom    = 8
# Probability [Q-value] = 0.423089
# Reduced statistic     = 1.01337
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 31.6412
# Data points           = 25
# Degrees of freedom    = 23
# Probability [Q-value] = 0.107839
# Reduced statistic     = 1.3757
# apec.kT lower bound:	-0.74568
# apec.kT upper bound:	1.1374
# apec.norm lower bound:	-3.84154e-06
# apec.norm upper bound:	3.93374e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           3.16592     -0.74568       1.1374
#    apec.norm     3.27461e-05 -3.84154e-06  3.93374e-06
# Loading data and model for region 16...
# read ARF file avery_17218_16.arf
# read RMF file avery_17218_16.rmf
# read ARF (background) file avery_17218_16_bkg.arf
# read RMF (background) file avery_17218_16_bkg.rmf
# read background file avery_17218_16_bkg.pi
# read ARF (background) file avery_17218_16_bkg.arf
# read RMF (background) file avery_17218_16_bkg.rmf
# read ARF file avery_18689_16.arf
# read RMF file avery_18689_16.rmf
# read ARF (background) file avery_18689_16_bkg.arf
# read RMF (background) file avery_18689_16_bkg.rmf
# read background file avery_18689_16_bkg.pi
# read ARF (background) file avery_18689_16_bkg.arf
# read RMF (background) file avery_18689_16_bkg.rmf
# Fitting for region 16...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.20521e+11
# Final fit statistic   = 9.0022 at function evaluation 13
# Data points           = 22
# Degrees of freedom    = 20
# Probability [Q-value] = 0.982882
# Reduced statistic     = 0.45011
# Change in statistic   = 1.20521e+11
#    apec.kT        4.23811      +/- 1.60128
#    apec.norm      2.66254e-05  +/- 3.41249e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.238108458168027, 2.6625409038966194e-05)
# statval        = 9.002199825787953
# istatval       = 120521021733.41943
# dstatval       = 120521021724.41724
# numpoints      = 22
# dof            = 20
# qval           = 0.9828817740656498
# rstat          = 0.45010999128939766
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 5.6431
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.958184
# Reduced statistic     = 0.434084
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.3591
# Data points           = 7
# Degrees of freedom    = 5
# Probability [Q-value] = 0.644806
# Reduced statistic     = 0.67182
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 9.0022
# Data points           = 22
# Degrees of freedom    = 20
# Probability [Q-value] = 0.982882
# Reduced statistic     = 0.45011
# apec.kT lower bound:	-1.27232
# apec.kT upper bound:	2.30113
# apec.norm lower bound:	-3.26084e-06
# apec.norm upper bound:	3.52171e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.23811     -1.27232      2.30113
#    apec.norm     2.66254e-05 -3.26084e-06  3.52171e-06
# Loading data and model for region 17...
# read ARF file avery_17218_17.arf
# read RMF file avery_17218_17.rmf
# read ARF (background) file avery_17218_17_bkg.arf
# read RMF (background) file avery_17218_17_bkg.rmf
# read background file avery_17218_17_bkg.pi
# read ARF (background) file avery_17218_17_bkg.arf
# read RMF (background) file avery_17218_17_bkg.rmf
# read ARF file avery_18689_17.arf
# read RMF file avery_18689_17.rmf
# read ARF (background) file avery_18689_17_bkg.arf
# read RMF (background) file avery_18689_17_bkg.rmf
# read background file avery_18689_17_bkg.pi
# read ARF (background) file avery_18689_17_bkg.arf
# read RMF (background) file avery_18689_17_bkg.rmf
# Fitting for region 17...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.13653e+11
# Final fit statistic   = 8.51387 at function evaluation 29
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.992551
# Reduced statistic     = 0.405422
# Change in statistic   = 1.13653e+11
#    apec.kT        4.31893      +/- 1.69036
#    apec.norm      2.71469e-05  +/- 3.38775e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.318934460321869, 2.7146938095230345e-05)
# statval        = 8.513867371012315
# istatval       = 113653331585.85828
# dstatval       = 113653331577.3444
# numpoints      = 23
# dof            = 21
# qval           = 0.9925508855691297
# rstat          = 0.4054222557624912
# message        = successful termination
# nfev           = 29
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 6.81979
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.911198
# Reduced statistic     = 0.524599
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 1.69407
# Data points           = 8
# Degrees of freedom    = 6
# Probability [Q-value] = 0.945578
# Reduced statistic     = 0.282346
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 8.51387
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.992551
# Reduced statistic     = 0.405422
# apec.kT lower bound:	-1.2042
# apec.kT upper bound:	2.37937
# apec.norm lower bound:	-3.29581e-06
# apec.norm upper bound:	3.42765e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.31893      -1.2042      2.37937
#    apec.norm     2.71469e-05 -3.29581e-06  3.42765e-06
# Loading data and model for region 18...
# read ARF file avery_17218_18.arf
# read RMF file avery_17218_18.rmf
# read ARF (background) file avery_17218_18_bkg.arf
# read RMF (background) file avery_17218_18_bkg.rmf
# read background file avery_17218_18_bkg.pi
# read ARF (background) file avery_17218_18_bkg.arf
# read RMF (background) file avery_17218_18_bkg.rmf
# read ARF file avery_18689_18.arf
# read RMF file avery_18689_18.rmf
# read ARF (background) file avery_18689_18_bkg.arf
# read RMF (background) file avery_18689_18_bkg.rmf
# read background file avery_18689_18_bkg.pi
# read ARF (background) file avery_18689_18_bkg.arf
# read RMF (background) file avery_18689_18_bkg.rmf
# Fitting for region 18...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.0545e+11
# Final fit statistic   = 13.4612 at function evaluation 27
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.919495
# Reduced statistic     = 0.611874
# Change in statistic   = 1.0545e+11
#    apec.kT        7.24949      +/- 4.23065
#    apec.norm      2.82154e-05  +/- 3.00493e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (7.249493709650167, 2.8215381326930258e-05)
# statval        = 13.461222945136242
# istatval       = 105449721741.13654
# dstatval       = 105449721727.67531
# numpoints      = 24
# dof            = 22
# qval           = 0.9194946781638895
# rstat          = 0.6118737702334656
# message        = successful termination
# nfev           = 27
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 10.0177
# Data points           = 15
# Degrees of freedom    = 13
# Probability [Q-value] = 0.692487
# Reduced statistic     = 0.770592
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.44353
# Data points           = 9
# Degrees of freedom    = 7
# Probability [Q-value] = 0.84117
# Reduced statistic     = 0.491932
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 13.4612
# Data points           = 24
# Degrees of freedom    = 22
# Probability [Q-value] = 0.919495
# Reduced statistic     = 0.611874
# apec.kT lower bound:	-2.83458
# apec.kT upper bound:	11.3427
# apec.norm lower bound:	-2.93611e-06
# apec.norm upper bound:	3.11628e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           7.24949     -2.83458      11.3427
#    apec.norm     2.82154e-05 -2.93611e-06  3.11628e-06
# Loading data and model for region 19...
# read ARF file avery_17218_19.arf
# read RMF file avery_17218_19.rmf
# read ARF (background) file avery_17218_19_bkg.arf
# read RMF (background) file avery_17218_19_bkg.rmf
# read background file avery_17218_19_bkg.pi
# read ARF (background) file avery_17218_19_bkg.arf
# read RMF (background) file avery_17218_19_bkg.rmf
# read ARF file avery_18689_19.arf
# read RMF file avery_18689_19.rmf
# read ARF (background) file avery_18689_19_bkg.arf
# read RMF (background) file avery_18689_19_bkg.rmf
# read background file avery_18689_19_bkg.pi
# read ARF (background) file avery_18689_19_bkg.arf
# read RMF (background) file avery_18689_19_bkg.rmf
# Fitting for region 19...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.21114e+11
# Final fit statistic   = 7.21306 at function evaluation 13
# Data points           = 22
# Degrees of freedom    = 20
# Probability [Q-value] = 0.995926
# Reduced statistic     = 0.360653
# Change in statistic   = 1.21114e+11
#    apec.kT        4.75353      +/- 2.1425
#    apec.norm      2.31932e-05  +/- 3.20868e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.753527230497974, 2.3193189122107812e-05)
# statval        = 7.21306039292843
# istatval       = 121113545176.39203
# dstatval       = 121113545169.17897
# numpoints      = 22
# dof            = 20
# qval           = 0.9959255505211007
# rstat          = 0.3606530196464215
# message        = successful termination
# nfev           = 13
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 4.41567
# Data points           = 14
# Degrees of freedom    = 12
# Probability [Q-value] = 0.974716
# Reduced statistic     = 0.367973
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 2.79739
# Data points           = 8
# Degrees of freedom    = 6
# Probability [Q-value] = 0.833813
# Reduced statistic     = 0.466232
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 7.21306
# Data points           = 22
# Degrees of freedom    = 20
# Probability [Q-value] = 0.995926
# Reduced statistic     = 0.360653
# apec.kT lower bound:	-1.54799
# apec.kT upper bound:	3.43824
# apec.norm lower bound:	-3.0819e-06
# apec.norm upper bound:	3.30379e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.75353     -1.54799      3.43824
#    apec.norm     2.31932e-05  -3.0819e-06  3.30379e-06
# Loading data and model for region 20...
# read ARF file avery_17218_20.arf
# read RMF file avery_17218_20.rmf
# read ARF (background) file avery_17218_20_bkg.arf
# read RMF (background) file avery_17218_20_bkg.rmf
# read background file avery_17218_20_bkg.pi
# read ARF (background) file avery_17218_20_bkg.arf
# read RMF (background) file avery_17218_20_bkg.rmf
# read ARF file avery_18689_20.arf
# read RMF file avery_18689_20.rmf
# read ARF (background) file avery_18689_20_bkg.arf
# read RMF (background) file avery_18689_20_bkg.rmf
# read background file avery_18689_20_bkg.pi
# read ARF (background) file avery_18689_20_bkg.arf
# read RMF (background) file avery_18689_20_bkg.rmf
# Fitting for region 20...
# Datasets              = 0, 1
# Method                = levmar
# Statistic             = chi2gehrels
# Initial fit statistic = 1.22631e+11
# Final fit statistic   = 10.0823 at function evaluation 28
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.977824
# Reduced statistic     = 0.480109
# Change in statistic   = 1.22631e+11
#    apec.kT        4.84578      +/- 2.38175
#    apec.norm      2.2893e-05   +/- 3.13453e-06
# datasets       = (0, 1)
# itermethodname = none
# methodname     = levmar
# statname       = chi2gehrels
# succeeded      = True
# parnames       = ('apec.kT', 'apec.norm')
# parvals        = (4.8457799518962545, 2.2892983438209964e-05)
# statval        = 10.082292683027704
# istatval       = 122630574358.34444
# dstatval       = 122630574348.26215
# numpoints      = 23
# dof            = 21
# qval           = 0.9778235357301707
# rstat          = 0.48010917538227166
# message        = successful termination
# nfev           = 28
# Dataset               = 0
# Statistic             = chi2gehrels
# Fit statistic value   = 6.17067
# Data points           = 16
# Degrees of freedom    = 14
# Probability [Q-value] = 0.962005
# Reduced statistic     = 0.440762
#
# Dataset               = 1
# Statistic             = chi2gehrels
# Fit statistic value   = 3.91162
# Data points           = 7
# Degrees of freedom    = 5
# Probability [Q-value] = 0.562209
# Reduced statistic     = 0.782324
#
# Datasets              = [0, 1]
# Statistic             = chi2gehrels
# Fit statistic value   = 10.0823
# Data points           = 23
# Degrees of freedom    = 21
# Probability [Q-value] = 0.977824
# Reduced statistic     = 0.480109
# apec.kT lower bound:	-1.63445
# apec.kT upper bound:	3.50257
# apec.norm lower bound:	-3.03064e-06
# apec.norm upper bound:	3.24436e-06
# Datasets              = 0, 1
# Confidence Method     = confidence
# Iterative Fit Method  = None
# Fitting Method        = levmar
# Statistic             = chi2gehrels
# confidence 1-sigma (68.2689%) bounds:
#    Param            Best-Fit  Lower Bound  Upper Bound
#    -----            --------  -----------  -----------
#    apec.kT           4.84578     -1.63445      3.50257
#    apec.norm      2.2893e-05 -3.03064e-06  3.24436e-06

# %% [markdown]
# ### 5. Compare By Hand Spectral Profiles to Vikhlinin Profiles

# %% [markdown]
# Also read in the Vikhlihin temperature profile from the Beads directory. This is all annoying, so I'm hiding these cells for cleanliness. You need to set your specific path to the final CCCPIV profiles here:

# %% [markdown]
# #### Read in Vikhlinin profiles

# %%
location_of_vikhlinin_tables = path_to_beads + 'Notebooks/Beads20/Chandra/final_cccp4_profiles/'

# %%
#read vikhlinin tprofile fit
vikhlinin_tprof_datfile_names = ['Bin', 'T(keV)', 'Terr-', 'Terr+', 'Terr-90percent', 'Terr+90percent', 'Abundance (solar)', 'Abundance_err (solar)', 'nH (1e20 cgs)', 'nH_err (1e20 cgs)', 'T syserr bkg', 'T syserr foregrd', 'G9']
vikhlinin_tprof = ascii.read(location_of_vikhlinin_tables + 'tprof.dat', names=vikhlinin_tprof_datfile_names)

# This file includes the inner and outer annuli for the temperature profile bins
# you need to include data_end because tprof is usually smaller by a few outer bins
vikhlinin_radii_names = ['BIN', 'RIN', 'ROUT']
vikhlinin_radii_bounds = ascii.read(location_of_vikhlinin_tables + 'tprof.rbounds', names=vikhlinin_radii_names, data_end = len(vikhlinin_tprof['Bin']))

# Calclate the bin center from radius
vikhlinin_bin_center_radius_kpc = ((vikhlinin_radii_bounds['RIN'] + vikhlinin_radii_bounds['ROUT']) / 2)* u.arcsec * kpc_per_arcsec
vikhlinin_bin_center_radius_err_kpc = ((vikhlinin_radii_bounds['ROUT'] - vikhlinin_radii_bounds['RIN']) / 2)* u.arcsec * kpc_per_arcsec

# %%
#parse temprature profile dictionary
tprof_par_dict = cf.parse_tprof_parfile(path_to_beads + 'Notebooks/Beads20/Chandra/final_cccp4_profiles/tprof.par')
(tfitx, tfity) = cf.vikhlinin_temperature_fit(tprof_par_dict)

# %% [markdown]
# #### Compare Tprofile

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, kTs.value,yerr=kT_errs.value, marker="o", ls='none', label='kT spectral fits from this Notebook') # ls=None doesn't work, stupidly

ax.set_xscale('log')


ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"kT (keV)") # for sur_bri units


# Also plot the Vikhlinin profiles for sanity
last_fit_annulus = 7
last_valid_annulus = len(vikhlinin_tprof['T(keV)']) # I only fit the temperature profile using data points from the first 7 annuli

# ax.plot(vikhlinin_bin_center_radius_kpc, vikhlinin_tprof['T(keV)'])
ax.plot(tfitx, tfity, label='Vikhlinin+06 fit using independent code')
ax.errorbar(vikhlinin_bin_center_radius_kpc[:last_fit_annulus].value, vikhlinin_tprof['T(keV)'][:last_fit_annulus].value, yerr=[-vikhlinin_tprof['Terr-'][:last_fit_annulus].value, vikhlinin_tprof['Terr+'][:last_fit_annulus].value], xerr=vikhlinin_bin_center_radius_err_kpc[:last_fit_annulus].value, ls='none', label='Vikhlinin temperature points')
# ax.errorbar(vikhlinin_bin_center_radius_kpc[last_fit_annulus:], vikhlinin_tprof['T(keV)'][last_fit_annulus:], yerr=[-vikhlinin_tprof['Terr-'][last_fit_annulus:].value, vikhlinin_tprof['Terr+'][last_fit_annulus:].value], xerr=vikhlinin_bin_center_radius_err_kpc[last_fit_annulus:].value, ls='none', label='Annuli ignored in fit')



ax.set_xlim(1, 300)
ax.set_ylim(0, 7)


ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')

ax2.set_xlabel('Radius (arcsec)')

ax.legend()

ax.set_title('SDSS 1531 X-ray Temperature Profile (two-method comparison)')
# Out:
# Text(0.5, 1.0, 'SDSS 1531 X-ray Temperature Profile (two-method comparison)')

# %% [markdown]
# Good! The spectral fits are completely consistent with the VO6 code results, which are totally custom and separate from this notebook

# %% [markdown]
# #### Compare electron density

# %% [markdown]
# Compute normalization

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, norms,yerr=norm_errs, xerr=radius_err_to_plot, marker="o", ls='none') # ls=None doesn't work, stupidly

ax.set_xscale('log')


ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"APEC Normalization") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')
# Out:
# Text(0.5, 0, 'Radius (arcsec)')

# %% [markdown]
# Compute the volume per annulus, which we need to convert norm to density

# %%
r_inner_in_kpc = rmin_rmax_in_pixel_units[:,0] * acis_pixel_scale * kpc_per_arcsec 
r_outer_in_kpc = rmin_rmax_in_pixel_units[:,1] * acis_pixel_scale * kpc_per_arcsec

volume = (4/3) * scipy.pi * (r_outer_in_kpc**3 - r_inner_in_kpc**3)
cm_per_arcmin =  cosmo.kpc_proper_per_arcmin(z).to(u.cm/u.arcmin)

volume_in_arcmin = volume.to(u.cm**3) / cm_per_arcmin**3

# %% [markdown]
# Compute the density array

# %% [markdown]
# `Apec` model normalization is $\eta = \frac{10^{-14}}{4\pi D_A^2(1+z)^2} \int n_e n_p dV$

# %%
electron_density = np.sqrt((norms * u.cm**-5 * 4 * np.pi * np.power(angular_diameter_distance.to(u.cm) * (1 + z), 2)) / (1.e-14 * 0.82 * volume.to(u.cm**3))) 
electron_density_err = electron_density / (2*norms) * norm_errs

# %%
#Load ACCEPT Table
main_accept_table = cf.parse_accept_table('accept_main_table.txt')
grouped_accept_table = main_accept_table.group_by('Name')

# %%
#vikhlinin profiles
sb_profile_fit_names = ['R', # radius in kpc, r=(r1+r2)/2 where r1 and r2 are the inner and outer radii of the annulus
                        'FIT', # Emission measure,  E=\int ne np dl, in units of cgs per kpc^2 (sorry :). E.g., you need to divide these numbers by 9.52141e+42 (i.e. kpc^2 in cm) to get to the cgs units. C.f. CCCP2 fig5.
                        'ne_np', # np * ne at radius r (cgs)
                        'sqrt(ne_np)', # sqrt(ne*np) at radius r (cgs units)
                        'outer_annulus_r', #r2 (outer annulus radius) in kpc, cf col 1
                        'gas_mass', # gas mass within r < r2, Msolar
                        'spherical_overdensity'] # Spherical overdensity of the gas mass with respect to the mean cosmic density of baryons.

sb_profile_fit = ascii.read (location_of_vikhlinin_tables + 'tot.fit.2',
                           names = sb_profile_fit_names,
                           data_end=87)
r = sb_profile_fit['R'] 

regrid_tfitx, regrid_tfity = cf.vikhlinin_temperature_fit(tprof_par_dict, r)
t_kev = regrid_tfity * u.keV

ne_np = sb_profile_fit['ne_np']
sqrt_ne_np = sb_profile_fit['sqrt(ne_np)']


# Alexey gives us ne * np. To convert this to ne, we assume that 
# ne = sqrt(ne^2) = sqrt(1.199 ne * np) where Z = ne / np = 1.199 is the 
# average nuclear mass for a plasma with 0.3 Zsolar metallicity, assuming abundances 
# from Anders & Grevesse (1989).

# use McDonald Z/3 metallicity values, i.e. 

n_e = np.sqrt(1.199 * ne_np)  * u.cm**-3

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, electron_density.value, xerr=radius_err_to_plot, yerr=electron_density_err.value, marker="o", ls='none', label='SDSS 1531') # ls=None doesn't work, stupidly

ax.set_xscale('log')

ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"Electron Density (cm$^{-3}$)") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

#vikhlinin
ax.plot(r, n_e, lw=3, label='v06')

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')

for i, (cluster_name, cluster_profile) in enumerate(zip(grouped_accept_table.groups.keys, grouped_accept_table.groups)):
    accept_radius = ((cluster_profile['Rout'] + cluster_profile['Rin']) / 2) * 1000 # Table radii are in Mpc

    # if you want the smooth, clean polynomial fit profiles, which *can* have unphysical behavior at low radii 
    r_fit, temperature_fit, pressure_fit, electron_density_fit, entropy_fit, tcool_fit, t_fit_err, p_fit_err, ed_fit_err, en_fit_err, tcool_fit_err= cf.fit_accept_clusters(cluster_profile)

    ax.plot(r_fit*1000, electron_density_fit, color='slategray', lw=0.3, alpha=0.2)
    ax.plot(accept_radius, cluster_profile['nelec'], zorder=1, alpha=0.3, color='slategray', linestyle='none', marker='o', markersize=0.8, label='ACCEPT Sample Profiles (Cavagnolo+09)' if i==0 else '')

ax.set_ylim(1e-3, 1e-1)

legend = ax.legend()

# the ACCEPT data points are tiny and quasi-transparent, making for terrible legend markers. Fix that manually
for lh in legend.legendHandles: 
    try:
        lh._legmarker.set_alpha(1)
        lh._legmarker.set_markersize(10)
    except AttributeError:
        # then you've hit the handles for the SDSS points - ax.errorbar doesn't have _legmarker attribute. just skip. 
        continue

# %% [markdown]
# #### Compare pressure profiles

# %% [markdown]
# $P = nkT$ where $n=n_e + n_H \approx 2n_e$ because $n_e = 1.2n_H$

# %%
pressure = (2 * electron_density * kTs).to(u.dyne/u.cm**2)
pressure_err  = pressure * cf.dm_error_prop([electron_density, kTs], [electron_density_err, kT_errs])

# %%
#vikhlinin 
n_p = n_e/1.199
n_h = n_e/1.2

vpressure_profile = ((n_e + n_p) * t_kev).to(u.dyne/u.cm**2)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, pressure.to(u.dyne/u.cm**2).value, xerr=radius_err_to_plot,yerr=pressure_err.value, marker="o", ls='none', label='SDSS 1531') # ls=None doesn't work, stupidly

ax.set_xscale('log')

ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"Pressure (dyne cm$^{-2}$)") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

#vikhlinin
ax.plot(r, vpressure_profile, lw=3, label='v06')

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')

ax.set_ylim(1e-12, 1e-8)


for i, (cluster_name, cluster_profile) in enumerate(zip(grouped_accept_table.groups.keys, grouped_accept_table.groups)):
    accept_radius = ((cluster_profile['Rout'] + cluster_profile['Rin']) / 2) * 1000 # Table radii are in Mpc

    # if you want the smooth, clean polynomial fit profiles, which *can* have unphysical behavior at low radii 
    r_fit, temperature_fit, pressure_fit, electron_density_fit, entropy_fit, tcool_fit, t_fit_err, p_fit_err, ed_fit_err, en_fit_err, tcool_fit_err= cf.fit_accept_clusters(cluster_profile)
    
    ax.plot(r_fit*1000, pressure_fit, color='slategray', lw=0.3, alpha=0.2)
    ax.plot(accept_radius, cluster_profile['Pitpl'], zorder=1, alpha=0.3, color='slategray', linestyle='none', marker='o', markersize=0.8, label='ACCEPT Pressure Profiles (Cavagnolo+09)' if i==0 else '')

legend = ax.legend()

# the ACCEPT data points are tiny and quasi-transparent, making for terrible legend markers. Fix that manually
for lh in legend.legendHandles: 
    try:
        lh._legmarker.set_alpha(1)
        lh._legmarker.set_markersize(10)
    except AttributeError:
        # then you've hit the handles for the SDSS points - ax.errorbar doesn't have _legmarker attribute. just skip. 
        continue

# %% [markdown]
# #### Compare Entropy Profiles

# %%
entropy  = kTs * np.power(electron_density, -2.0/3.0)
entropy_err = entropy * cf.dm_error_prop([kTs.value, np.power(electron_density, -2/3).value], 
                [kT_errs.value, cf.exp_error_prop(electron_density, electron_density_err, -2/3) ])

# vikhlinin
ventropy_profile = t_kev * n_e**(-2/3)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, entropy.value, xerr=radius_err_to_plot, yerr=entropy_err.value, marker="o", ls='none') # ls=None doesn't work, stupidly

ax.set_xscale('log')

ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"Entropy (keV cm$^{2}$)") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')

#vikhlinin
ax.plot(r, ventropy_profile, lw=3, label='v06')

for i, (cluster_name, cluster_profile) in enumerate(zip(grouped_accept_table.groups.keys, grouped_accept_table.groups)):
    accept_radius = ((cluster_profile['Rout'] + cluster_profile['Rin']) / 2) * 1000 # Table radii are in Mpc

    # if you want the smooth, clean polynomial fit profiles, which *can* have unphysical behavior at low radii 
    r_fit, temperature_fit, pressure_fit, electron_density_fit, entropy_fit, tcool_fit, t_fit_err, p_fit_err, ed_fit_err, en_fit_err, tcool_fit_err= cf.fit_accept_clusters(cluster_profile)
    
    ax.plot(r_fit*1000, entropy_fit, color='slategray', lw=0.3, alpha=0.2)
    ax.plot(accept_radius, cluster_profile['Kitpl'], zorder=1, alpha=0.3, color='slategray', linestyle='none', marker='o', markersize=0.8, label='ACCEPT Entropy Profiles (Cavagnolo+09)' if i==0 else '')

legend = ax.legend()

# the ACCEPT data points are tiny and quasi-transparent, making for terrible legend markers. Fix that manually
for lh in legend.legendHandles: 
    try:
        lh._legmarker.set_alpha(1)
        lh._legmarker.set_markersize(10)
    except AttributeError:
        # then you've hit the handles for the SDSS points - ax.errorbar doesn't have _legmarker attribute. just skip. 
        continue
ax.set_ylim(1, 10000)
# Out:
# (1, 10000)

# %% [markdown]
# ### Compute the Luminsosity per annulus
# GT needs to confirm that `cel_flux` is in the correct units! Treat this one with caution and don't use it in the paper please!

# %%
luminosity  = cel_flux * u.erg / u.s / u.cm**2  * 4.0 * np.pi * np.power(cosmo.luminosity_distance(z), 2) # in erg/s
luminosity_err  = luminosity * scipy.log(10) * cel_flux_err
luminosity.to(u.erg/u.s)
# Out:
# <Quantity [1.97046073e+50, 1.87452137e+50, 1.09123278e+50, 5.33472364e+49,
#            3.22592656e+49, 2.09344395e+49, 1.98273556e+49, 1.38737593e+49,
#            1.04201746e+49, 8.29043020e+48, 8.54937748e+48, 6.79109540e+48,
#            4.05296116e+48, 4.60115866e+48, 3.69120127e+48, 4.22336077e+48,
#            2.47793159e+48, 2.64428483e+48, 2.83432978e+48, 2.26081825e+48,
#            1.77326591e+48] erg / s>

# %% [markdown]
# #### Compare Cooling Times

# %% [markdown]
# What is all of this?! See Eqn. 35 here: https://arxiv.org/pdf/0706.1274.pdf

# %%
def tcool(electron_density, temperature_kev):
    #see mcdonald (2018) eqn 2
    proton_density = 0.92 * electron_density
    hydrogen_density = 0.83 * electron_density

    cooling_time = ((3/2) * ((electron_density + proton_density ) * temperature_kev)
                    /(electron_density * hydrogen_density * cf.coolingFunction(temperature_kev))).cgs
                    
    return cooling_time

# %%
cooling_time = tcool(electron_density, kTs)
cool_func_err = cf.dm_error_prop([kTs**-1.7, kTs**0.5], [cf.exp_error_prop(kTs, kT_errs, -1.7), 
                    cf.exp_error_prop(kTs, kT_errs, 0.5)]) * cf.coolingFunction(kTs)

cooling_time_err = cooling_time * cf.dm_error_prop([pressure.value, np.power(electron_density, 2).value, cf.coolingFunction(kTs).value],
                    [pressure_err.value, cf.exp_error_prop(electron_density, electron_density_err, 2).value, cool_func_err])


#vikhlinin 
vcooling_time = tcool(n_e, t_kev)

# %%
# #eqn from mcdonald 2019
# gamma=5/3
# cooling_time = (pressure/((gamma - 1) * electron_density * (electron_density/1.199) * cf.coolingFunction(kTs))).cgs

# # (( 3 * (electron_density + (electron_density/1.07)) * kTs)
# #                 /(2*electron_density * (electron_density/1.07) * cf.coolingFunction(kTs))).cgs
# #(3/2) * (1.89 * pressure) / (electron_density**2 / 1.07) / cf.coolingFunction(kTs).to(u.keV * u.cm**3/u.s)

# #(( 3 * (electron_density + (electron_density/1.199)) * kTs)
#                 #/(2*electron_density * (electron_density/1.199) * cf.coolingFunction(kTs))).cgs
# #gamma=5/3
# #(pressure/((gamma - 1) * electron_density * (electron_density/1.199) * cf.coolingFunction(kTs))).cgs
# #(3/2) * (1.89 * pressure) / (electron_density**2 / 1.07) / cf.coolingFunction(kTs).to(u.keV * u.cm**3/u.s)

# cool_func_err = cf.dm_error_prop([kTs**-1.7, kTs**0.5], [cf.exp_error_prop(kTs, kT_errs, -1.7), 
#                     cf.exp_error_prop(kTs, kT_errs, 0.5)]) * cf.coolingFunction(kTs)

# cooling_time_err = cooling_time * cf.dm_error_prop([pressure.value, np.power(electron_density, 2).value, cf.coolingFunction(kTs).value],
#                     [pressure_err.value, cf.exp_error_prop(electron_density, electron_density_err, 2).value, cool_func_err])

# #vikhlinin 
# vcooling_time = (vpressure_profile/((gamma - 1) * n_e * (n_e/1.199) * cf.coolingFunction(t_kev))).cgs

# #(( 3 * (n_e + n_p) * t_kev)/(2*n_e*n_e/1.07 * cf.coolingFunction(t_kev))).cgs
# #(3/2) * (1.89 * vpressure_profile) / (n_e**2 / 1.07) / cf.coolingFunction(t_kev).to(u.keV * u.cm**3/u.s)

# #(( 3 * (n_e + n_p) * t_kev)/(2*n_e*n_h * cf.coolingFunction(t_kev))).cgs

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.errorbar(radius_to_plot, cooling_time.to(u.Gyr).value, xerr=radius_err_to_plot, yerr=cooling_time_err.to(u.Gyr).value, marker="o", ls='none') # ls=None doesn't work, stupidly

ax.set_xscale('log')

ax.set_xlabel("Radius (kpc)")
ax.set_ylabel(r"Cooling Time (Gyr)") # for sur_bri units
# ax.set_ylabel(r"Flux (photons cm$^{-2}$ arcsec$^{-2}$ s$^{-1}$)") # for flux units

ax.set_yscale('log')
ax.set_xscale('log')

ax.set_xlim(1, 300)

ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim() / kpc_per_arcsec.value)
ax2.grid(None)
ax2.set_xscale('log')
ax2.set_xlabel('Radius (arcsec)')

#vikhlinin
ax.plot(r, (vcooling_time).to(u.Gyr), lw=3, label='v06')


for i, (cluster_name, cluster_profile) in enumerate(zip(grouped_accept_table.groups.keys, grouped_accept_table.groups)):
    accept_radius = ((cluster_profile['Rout'] + cluster_profile['Rin']) / 2) * 1000 # Table radii are in Mpc

    # if you want the smooth, clean polynomial fit profiles, which *can* have unphysical behavior at low radii 
    r_fit, temperature_fit, pressure_fit, electron_density_fit, entropy_fit, tcool_fit, t_fit_err, p_fit_err, ed_fit_err, en_fit_err, tcool_fit_err= cf.fit_accept_clusters(cluster_profile)

    ax.plot(r_fit*1000, tcool_fit.to(u.Gyr), color='slategray', lw=0.3, alpha=0.2)
    ax.plot(accept_radius, cluster_profile['tcool32'], zorder=1, alpha=0.3, color='slategray', linestyle='none', marker='o', markersize=0.8, label='ACCEPT Cooling Time Profiles (Cavagnolo+09)' if i==0 else '')

legend = ax.legend()

# the ACCEPT data points are tiny and quasi-transparent, making for terrible legend markers. Fix that manually
for lh in legend.legendHandles: 
    try:
        lh._legmarker.set_alpha(1)
        lh._legmarker.set_markersize(10)
    except AttributeError:
        # then you've hit the handles for the SDSS points - ax.errorbar doesn't have _legmarker attribute. just skip. 
        continue

ax.set_ylim(0.1, 100)
ax.axhline(10, color='slategray', linestyle='--')
ax.axvline(60, color='slategray', linestyle='--')
ax.text(2, 2, 'Cool Core within inner ~60 kpc')
# Out:
# Text(2, 2, 'Cool Core within inner ~60 kpc')

# %% [markdown]
# #### Compare Freefall Times

# %%
def slope(x1,x2,y1,y2):
    return (y2 - y1)/(x2 - x1)

def grav_accel(temperature_kev, pressure, radius):
    mu_mp = const.m_p
    dp_dr = np.zeros(len(radius))
    for i in np.arange(0, len(dp_dr)):
        if i == len(dp_dr) - 1:
            dp_dr[i] = np.nan
        else:
            dp_dr[i] = slope(radius[i], radius[i+1], pressure[i], pressure[i+1]).cgs.value

    rg = - temperature_kev.cgs / mu_mp.cgs * dp_dr * u.Ba/u.cm
    return rg

#cant figure out why this is wrong. come back later

# %%
vt_freefall = np.sqrt((2 * np.power(sb_profile_fit['R'] * u.kpc, 3))/
                        (const.G * sb_profile_fit['gas_mass'] * u.solMass)).to(u.Gyr)

# %%
#ratio of tcool/tff. 
# SHould be less than 20 for presence of molecular gas
# tcool_tff_ratio = (cooling_time/t_freefall).cgs
vtcool_tff_ratio = (vcooling_time/vt_freefall).cgs

fig, ax = plt.subplots(figsize=(10,10))

# ax.loglog(radius_to_plot, tcool_tff_ratio, lw=3)
#vikhlinin
ax.loglog(r, vtcool_tff_ratio, lw=3, label='v06')

ax.axhline(10,  color='slategray', ls='--', lw=1.5, label='tcool/tff = 10')
ax.axhline(1,  color='slategray', ls=':', lw=1.5, label='tcool/tff = 1')

ax.legend()
ax.set_ylabel(r'$t_{cool}/t_{freefall}$')
ax.set_xlabel(r'Radius (kpc)')

ax.set_xlim(1, 300)
# Out:
# (1, 300)
